# %%
from langchain_ollama import OllamaLLM
from langchain_core.prompts import PromptTemplate

model=OllamaLLM(model="llama3.2")
model.invoke("the sky is ")
# Out:
# "...blue, but that's not always the case. The color of the sky can change depending on various factors such as:\n\n1. Time of day: During sunrise and sunset, the sky can take on hues of red, orange, pink, and purple.\n2. Weather conditions: Clouds, fog, and haze can alter the appearance of the sky, making it appear gray, white, or even dark.\n3. Atmospheric conditions: Dust, pollution, and smoke in the air can affect the color of the sky.\n4. Location: The color of the sky can vary depending on the time of day and location due to the Earth's curvature and atmospheric conditions.\n\nSo, while blue is a common color associated with a clear sky, it's not always the case!"

# %%
template=PromptTemplate.from_template("""Answer the question based on the 
    context below. If the question cannot be answered using the information 
    provided, answer with "I don't know".
Context: {context}
Question: {question}
Answer:
""")
prompt=template.invoke({"context":"""The most recent advancements in NLP are being driven by Large
        Language Models (LLMs). These models outperform their smaller 
        counterparts and have become invaluable for developers who are creating 
        applications with NLP capabilities. Developers can tap into these 
        models through Hugging Face's `transformers` library, or by utilizing 
        OpenAI and Cohere's offerings through the `openai` and `cohere` 
        libraries, respectively.The most recent advancements in NLP are being driven by Large
        Language Models (LLMs). These models outperform their smaller 
        counterparts and have become invaluable for developers who are creating 
        applications with NLP capabilities. Developers can tap into these 
        models through Hugging Face's `transformers` library, or by utilizing 
        OpenAI and Cohere's offerings through the `openai` and `cohere` 
        libraries, respectively.""","question":"Which model providers offer LLMs?"})

# %%
model.invoke(prompt)
# Out:
# 'The question cannot be answered as it is phrased in the negative. However, I can provide an answer to the inverse of the question.\n\nThere are at least two model providers mentioned that offer Large Language Models (LLMs):\n\n1. Hugging Face\n2. OpenAI\n3. Cohere'

# %%
from langchain_core.prompts import ChatPromptTemplate
template=ChatPromptTemplate.from_messages([('system',''''Answer the question based on the context below. If the 
        question cannot be answered using the information provided, answer with 
        "I don\'t know".'''),('human','context:{context}'),('human','question:{question}')])
p=template.invoke({"context":"""The most recent advancements in NLP are being driven by Large
        Language Models (LLMs). These models outperform their smaller 
        counterparts and have become invaluable for developers who are creating 
        applications with NLP capabilities. Developers can tap into these 
        models through Hugging Face's `transformers` library, or by utilizing 
        OpenAI and Cohere's offerings through the `openai` and `cohere` 
        libraries, respectively.The most recent advancements in NLP are being driven by Large
        Language Models (LLMs). These models outperform their smaller 
        counterparts and have become invaluable for developers who are creating 
        applications with NLP capabilities. Developers can tap into these 
        models through Hugging Face's `transformers` library, or by utilizing 
        OpenAI and Cohere's offerings through the `openai` and `cohere` 
        libraries, respectively.""","question":"Which model providers offer LLMs?"})

# %%
model.invoke(p)
# Out:
# 'The answer is:\n\n1. Hugging Face\n2. OpenAI\n3. Cohere'

# %%
# from langchain_core.pydantic_v1 import BaseModel
# from pydantic.v1 import BaseModel?
from pydantic import BaseModel
from langchain_ollama import ChatOllama
class AnswerWithJustification(BaseModel):
    """'An answer to the user's question along with justification for the 
        answer.
    """
    answer:str
    '''
    answer to the user question
    '''
    justification:str
    '''
     justify the answer 
    '''
llm=ChatOllama(model='llama3.2',temperature=0)
structure_llm=llm.with_structured_output(AnswerWithJustification)
structure_llm.invoke('which is better 1kg gold or 2kg silver,which one will you suggeut me to buy')
# Out:
# AnswerWithJustification(answer="I can't give you financial advice. I'd be happy to provide general information about gold and silver.", justification="The value of gold and silver can fluctuate based on market conditions, so it's difficult to say which one is better without knowing the current market prices and your personal investment goals. If you're looking for a long-term investment, consider consulting with a financial advisor or conducting your own research.")

# %%
# from langchain_core.pydantic_v1 import BaseModel
from pydantic import BaseModel
from langchain_ollama import ChatOllama
class AnswerWithJustification(BaseModel):
    '''An answer to the user's question along with justification for the 
            answer.'''
    answer: str
    '''The answer to the user's question'''
    justification: str
    '''Justification for the answer'''
llm = ChatOllama(model="llama3.2", temperature=0)
structured_llm = llm.with_structured_output(AnswerWithJustification)
structured_llm.invoke("""What weighs more, a pound of bricks or a pound 
    of feathers""")
# Out:
# AnswerWithJustification(answer='They weigh the same', justification="One pound is a unit of weight or mass, and it's defined as equal to 16 ounces. Regardless of whether you have a pound of bricks or a pound of feathers, they both weigh the same amount, one pound.")

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser
parser=CommaSeparatedListOutputParser()
items=parser.invoke('apple, banana,cheery')
print(items)
# Out:
# ['apple', 'banana', 'cheery']

# %%
llm.invoke("hi, there")
# Out:
# AIMessage(content='How can I assist you today?', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-07T05:09:42.7448473Z', 'done': True, 'done_reason': 'stop', 'total_duration': 985748400, 'load_duration': 813381500, 'prompt_eval_count': 28, 'prompt_eval_duration': 40940000, 'eval_count': 8, 'eval_duration': 104734000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019ea07c-9cfc-7e90-b385-1e4e04a78b6c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 8, 'total_tokens': 36})

# %%
llm.batch(["hi, there ","bye"])
# Out:
# [AIMessage(content="Hello! It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-07T05:09:44.1992353Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1403918500, 'load_duration': 874541900, 'prompt_eval_count': 29, 'prompt_eval_duration': 37423000, 'eval_count': 25, 'eval_duration': 323081000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019ea07c-a108-7b72-a25b-f0feb7e30ea7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 29, 'output_tokens': 25, 'total_tokens': 54}),
# ...

# %%
for t in llm.stream("bye"):
    print(t)
# Out:
# content='By' additional_kwargs={} response_metadata={} id='lc_run--019ea07c-a69f-7f50-8e26-43daee457d3c' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='e' additional_kwargs={} response_metadata={} id='lc_run--019ea07c-a69f-7f50-8e26-43daee457d3c' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content='!' additional_kwargs={} response_metadata={} id='lc_run--019ea07c-a69f-7f50-8e26-43daee457d3c' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' Have' additional_kwargs={} response_metadata={} id='lc_run--019ea07c-a69f-7f50-8e26-43daee457d3c' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' a' additional_kwargs={} response_metadata={} id='lc_run--019ea07c-a69f-7f50-8e26-43daee457d3c' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# content=' great' additional_kwargs={} response_metadata={} id='lc_run--019ea07c-a69f-7f50-8e26-43daee457d3c' tool_calls=[] invalid_tool_calls=[] tool_call_chunks=[]
# ...

# %%
from langchain_core.runnables import chain

template=ChatPromptTemplate.from_messages([
 ('system','you are the helping assisant to me'),('human','{question}')
])

@chain
def chatbot(value):
    prompt=template.invoke(value)
    return llm.invoke(prompt)

chatbot.invoke({'question':'Which model providers offer LLMs?"'})
# Out:
# AIMessage(content='Several model providers offer Large Language Models (LLMs). Here are some of the most notable ones:\n\n1. **Hugging Face**: Hugging Face is a popular platform that offers a wide range of pre-trained LLMs, including BERT, RoBERTa, and DistilBERT.\n2. **Google**: Google Cloud offers several LLMs, including BERT, T5, and BigBird.\n3. **Amazon**: Amazon SageMaker offers a range of pre-trained LLMs, including BERT, RoBERTa, and XLNet.\n4. **Microsoft**: Microsoft Azure offers several LLMs, including BERT, RoBERTa, and LaMDA.\n5. **OpenAI**: OpenAI is the company behind the popular LLM model, GPT-3.\n6. **Meta AI**: Meta AI offers a range of pre-trained LLMs, including BART, T5, and XLNet.\n7. **DALL-E**: DALL-E is a model provider that specializes in generating images from text prompts using LLMs.\n\nThese are just a few examples of the many model providers that offer LLMs. The landscape is constantly evolving, with new models and providers emerging all the time.\n\nWou
# ...

# %%
@chain
def chatbot(values):
    prompt = template.invoke(values)
    for token in model.stream(prompt):
        yield token

# %%
@chain
async def chatbot(value):
    prompt= await template.ainvoke(value)
    return await llm.ainvoke(prompt)

await chatbot.ainvoke({'question':'Which model providers offer LLMs?"'})
# Out:
# AIMessage(content="Several model providers offer Large Language Models (LLMs). Here are some of the most notable ones:\n\n1. **Hugging Face**: Hugging Face is a popular platform that offers a wide range of pre-trained LLMs, including BERT, RoBERTa, and XLNet. They also provide a model hub where developers can upload and share their own models.\n2. **Google Cloud AI Platform**: Google Cloud AI Platform offers a range of pre-trained LLMs, including BERT, T5, and BigBird. They also provide a model management service that allows users to deploy and manage their own models.\n3. **Amazon SageMaker**: Amazon SageMaker is a fully managed service that provides access to a range of pre-trained LLMs, including BERT, RoBERTa, and XLNet. Users can also train their own models using the platform's auto-pilot feature.\n4. **Microsoft Azure Machine Learning**: Microsoft Azure Machine Learning offers a range of pre-trained LLMs, including BERT, T5, and BigBird. They also provide a model management ser
# ...

# %%
c=template | llm
c.invoke({'question':'Which model providers offer LLMs?"'})
# Out:
# AIMessage(content="Several model providers offer Large Language Models (LLMs). Here are some of the most notable ones:\n\n1. **Hugging Face**: Hugging Face is a popular platform that offers a wide range of pre-trained LLMs, including BERT, RoBERTa, and XLNet. They also provide a model hub where developers can upload and share their own models.\n2. **Google Cloud AI Platform**: Google Cloud AI Platform offers a range of pre-trained LLMs, including BERT, T5, and BigBird. They also provide a model management service that allows users to deploy and manage their own models.\n3. **Amazon SageMaker**: Amazon SageMaker is a fully managed service that provides access to a range of pre-trained LLMs, including BERT, RoBERTa, and XLNet. Users can also train their own models using the platform's auto-pilot feature.\n4. **Microsoft Azure Machine Learning**: Microsoft Azure Machine Learning offers a range of pre-trained LLMs, including BERT, T5, and BigBird. They also provide a model management ser
# ...

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader('text.txt', encoding="utf-8")
loader.load()
# Out:
# WARNING:tensorflow:From C:\Users\91830\anaconda3\envs\genai_env\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ...

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("./text.txt", encoding="utf-8")
loader.load()
# Out:
# [Document(metadata={'source': './text.txt'}, page_content='Consider these three words: lion, pet, and dog. Intuitively, which pair of these words\nshare similar characteristics to each other at first glance? The obvious answer is pet\nand dog. But computers do not have the ability to tap into this intuition or nuanced\nunderstanding of the English language. In order for a computer to differentiate\nbetween a lion, pet, or dog, you need to be able to translate them into the language of computers, which is numbers.\nOne effective way to calculate the degree of similarity between two vectors in a\nmultidimensional space is called cosine similarity. Cosine similarity computes the dot\nproduct of vectors and divides it by the product of their magnitudes to output a\nnumber between –1 and 1, where 0 means the vectors share no correlation, –1 means\nthey are absolutely dissimilar, and 1 means they are absolutely similar. So, in the case\nof our three words here, the cosine similarity betwee
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader
loader=WebBaseLoader("https://docs.langchain.com/")
loader.load()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader('Hema Sai Reddy_AIML (2).pdf')
loader.load()
# Out:
# [Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-05-15T13:53:36+00:00', 'title': 'Hema Sai Reddy Resume', 'moddate': '2026-05-15T13:53:36+00:00', 'source': 'Hema Sai Reddy_AIML (2).pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='1  \nHema Sai Reddy Anam \nEmail: anamhemasaireddy@gmail.com| Phone: +91 9392468946 |LinkedIn | GitHub \nSUMMARY \nHighly skilled Machine Learning Engineer with a focus on building production -ready Generative AI and \nRAG pipelines. I specialize in designing end -to-end ML solutions, from optimizing LLM performance with \nprompt engineering to deploying scalable REST APIs using FastAPI and Docker. With strong fundamentals \nin Python and OOPs, I am dedicated to delivering high -impact AI systems that solve complex business \nchallenges through responsible and innovative model development.  \nSKILLS \n \nLanguages & Core Fundamentals: Python, Java, SQL, JavaScript,  HTML, CSS,  O
# ...

# %%
from langchain_text_splitters import  RecursiveCharacterTextSplitter
loader=TextLoader('text.txt', encoding="utf-8")
doc=loader.load()
splitter=RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)
splitted_docs=splitter.split_documents(doc)
splitted_docs
# Out:
# [Document(metadata={'source': 'text.txt'}, page_content='Consider these three words: lion, pet, and dog. Intuitively, which pair of these words\nshare similar characteristics to each other at first glance? The obvious answer is pet\nand dog. But computers do not have the ability to tap into this intuition or nuanced\nunderstanding of the English language. In order for a computer to differentiate\nbetween a lion, pet, or dog, you need to be able to translate them into the language of computers, which is numbers.\nOne effective way to calculate the degree of similarity between two vectors in a\nmultidimensional space is called cosine similarity. Cosine similarity computes the dot\nproduct of vectors and divides it by the product of their magnitudes to output a\nnumber between –1 and 1, where 0 means the vectors share no correlation, –1 means\nthey are absolutely dissimilar, and 1 means they are absolutely similar. So, in the case\nof our three words here, the cosine similarity between 
# ...

# %%
from langchain_text_splitters import (Language, RecursiveCharacterTextSplitter)
Python_code="""
def hello_world():
    print("Hello, World!")
# Call the function
hello_world()
"""
split=RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON,
    chunk_size=50,
    chunk_overlap=0
)
splited_code=split.create_documents([Python_code])
splited_code
# Out:
# [Document(metadata={}, page_content='def hello_world():\n    print("Hello, World!")'),
#  Document(metadata={}, page_content='# Call the function\nhello_world()')]

# %%
markdown_text = """
# LangChain
⚡ Building applications with LLMs through composability ⚡
## Quick Install
```bash
pip install langchain
```
As an open source project in a rapidly developing field, we are extremely open 
    to contributions.
"""

# %%
mg_splitted=RecursiveCharacterTextSplitter.from_language(
     language=Language.MARKDOWN,
     chunk_size=60,chunk_overlap=0
)
mg_split=mg_splitted.create_documents([markdown_text],[{'source':'https://docs.langchain.com/'}])
mg_split
# Out:
# [Document(metadata={'source': 'https://docs.langchain.com/'}, page_content='# LangChain'),
#  Document(metadata={'source': 'https://docs.langchain.com/'}, page_content='⚡ Building applications with LLMs through composability ⚡'),
#  Document(metadata={'source': 'https://docs.langchain.com/'}, page_content='## Quick Install\n```bash\npip install langchain'),
#  Document(metadata={'source': 'https://docs.langchain.com/'}, page_content='```'),
#  Document(metadata={'source': 'https://docs.langchain.com/'}, page_content='As an open source project in a rapidly developing field, we'),
#  Document(metadata={'source': 'https://docs.langchain.com/'}, page_content='are extremely open'),
#  Document(metadata={'source': 'https://docs.langchain.com/'}, page_content='to contributions.')]

# %%
from langchain_ollama import OllamaEmbeddings
embed=OllamaEmbeddings(model='mxbai-embed-large:latest')
embeddings=embed.embed_documents(['hi there','hello','pet','dog','loin'])

# %%
loader=TextLoader('text.txt',encoding='utf-8')
d=loader.load()

# %%
text_split=RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)
chunks=text_split.split_documents(d)
embedding=embed.embed_documents([chunk.page_content for chunk in chunks])

# %%
from langchain_community.document_loaders import TextLoader
from langchain_core.documents import Document
from langchain_ollama import OllamaEmbeddings
from langchain_postgres.vectorstores import PGVector
from langchain_text_splitters import RecursiveCharacterTextSplitter
import uuid

raw_document=TextLoader('text.txt',encoding='utf-8').load()
text_splitter=RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
)
chunk_document=text_splitter.split_documents(raw_document)
embeds=OllamaEmbeddings(model='mxbai-embed-large:latest')
connection='postgresql+psycopg://langchain:langchain@localhost:6024/langchain'
vector_db=PGVector.from_documents(chunk_document,embeds,connection=connection)

# %%
vector_db.similarity_search('query',k=4)
# Out:
# [Document(id='d859ffd4-763c-4fad-95a3-423d662a1a7c', metadata={'source': 'text.txt'}, page_content='•You can “travel” the “meaning” space by using the elementary math operations •\nof addition and subtraction: for instance, the operation king – man + woman\n= queen. If you take the meaning (or semantic embedding) of king, subtract\nthe meaning of man, presumably you arrive at the more abstract meaning of\nmonarch, at which point, if you add the meaning of woman, you’ve arrived close\nto the meaning (or embedding) of the word queen.\n•There are models that can produce embeddings for nontext content, for instance, •\nimages, videos, and sounds, in addition to text. This enables, for instance, finding\nimages that are most similar or relevant for a given sentence.\nEmbeddings: Converting Text to Numbers | 29\nWe won’t explore all of these attributes in this book, but it’s useful to know they can be\nused for a number of applications such as:\nSearch\nFinding the most relevant documents 
# ...

# %%
ids=[str(uuid.uuid4()),str(uuid.uuid4())]
vector_db.add_documents(
    [
        Document(page_content="there are cute cats in the pond",
                  metadata={"location": "pond", "topic": "animals"}),
        Document(page_content="ducks are also in the same pond",
                  metadata={"location": "pond", "topic": "animals"}),
        
    ],id=ids
    
)
# Out:
# ['4b639900-3100-4dd8-92f1-52567b70e257',
#  '9b2d9a81-9749-47ee-b473-f100285ed6ba']

# %%
vector_db.delete(id=[1])

# %%
from langchain_classic.indexes import SQLRecordManager, index


collection_name="mY_docs"
namespace='my_docs_namespace'
vectorstore = PGVector(
embeddings=embeds,
collection_name=collection_name,
connection=connection,
use_jsonb=True,
)

record_manager = SQLRecordManager(
namespace,
db_url="postgresql+psycopg://langchain:langchain@localhost:6024/langchain",
)

record_manager.create_schema()

# %%
docs = [
Document(page_content='there are cats in the pond', metadata={
"id": 1, "source": "cats.txt"}),
Document(page_content='ducks are also found in the pond', metadata={
"id": 2, "source": "ducks.txt"}),
]

# %%
index_1 = index(
docs,
record_manager,
vectorstore,
cleanup="incremental",  # prevent duplicate documents
source_id_key="source",  # use the source field as the source_id
)
print("Index attempt 1:", index_1)
# Out:
# C:\Users\91830\anaconda3\envs\genai_env\Lib\site-packages\langchain_core\indexing\api.py:409: UserWarning: Using SHA-1 for document hashing. SHA-1 is *not* collision-resistant; a motivated attacker can construct distinct inputs that map to the same fingerprint. If this matters in your threat model, switch to a stronger algorithm such as 'blake2b', 'sha256', or 'sha512' by specifying  `key_encoder` parameter in the `index` or `aindex` function.
#   _warn_about_sha1()
# Index attempt 1: {'num_added': 2, 'num_updated': 0, 'num_skipped': 0, 'num_deleted': 0}

# %%
index_2 = index(
docs,
record_manager,
vectorstore,
cleanup="incremental",
source_id_key="source",
)
print("Index attempt 2:", index_2)
# Out:
# Index attempt 2: {'num_added': 0, 'num_updated': 0, 'num_skipped': 2, 'num_deleted': 0}

# %%
docs[1].metadata={"id": 2, "source": "cat.txt"}
index_3 = index(
docs,
record_manager,
vectorstore,
cleanup="incremental",
source_id_key="source",
)
print("Index attempt 3:", index_3)
# Out:
# Index attempt 3: {'num_added': 1, 'num_updated': 0, 'num_skipped': 1, 'num_deleted': 0}

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_ollama import OllamaEmbeddings
from langchain_postgres.vectorstores import PGVector
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel
from langchain_core.runnables import RunnablePassthrough
from langchain_ollama import ChatOllama
from langchain_core.documents import Document
from langchain_classic.retrievers.multi_vector import MultiVectorRetriever
from langchain_classic.storage import InMemoryStore
import uuid

connection = "postgresql+psycopg://langchain:langchain@localhost:6024/langchain"
collection_name = "summaries"

embeds=OllamaEmbeddings(model='mxbai-embed-large:latest')

loader = TextLoader("text.txt", encoding="utf-8")
docs = loader.load()

print("length of loaded docs: ", len(docs[0].page_content))

splitter=RecursiveCharacterTextSplitter(
         chunk_size=1000,
         chunk_overlap=200,
    )
chunks=splitter.split_documents(docs)

prompt_text = "Summarize the following document:\n\n{doc}"

prompt=ChatPromptTemplate.from_template(prompt_text)
llm=ChatOllama(temperature=0,model='llama3.2')
summarize_chain={"doc":lambda x:x.page_content} | prompt | llm |StrOutputParser()

summaries=summarize_chain.batch(chunks,{"max_concurrency":5})
# Out:
# length of loaded docs:  3605

# %%
vectorstore = PGVector(
embeddings=embeds,
collection_name=collection_name,
connection=connection,
use_jsonb=True,
)

store = InMemoryStore()
id_key = "doc_id"

retriever = MultiVectorRetriever(
vectorstore=vectorstore,
docstore=store,
id_key=id_key,
)

doc_ids = [str(uuid.uuid4()) for _ in chunks]

summary_docs = [
Document(page_content=s, metadata={id_key: doc_ids[i]})
for i, s in enumerate(summaries)
]

retriever.vectorstore.add_documents(summary_docs)

retriever.docstore.mset(list(zip(doc_ids, chunks)))

sub_docs = retriever.vectorstore.similarity_search(
"chapter on philosophy", k=2)

retrieved_docs = retriever.invoke("what is embeddings")

# %%
print(retrieved_docs)
# Out:
# [Document(metadata={'source': 'text.txt'}, page_content='used for a number of applications such as:\nSearch\nFinding the most relevant documents for a new query\nClustering\nGiven a body of documents, dividing them into groups (for instance, topics)\nClassification\nAssigning a new document to a previously identified group or label (for instance,\na topic)\nRecommendation\nGiven a document, surfacing similar documents\nDetecting anomalies\nIdentifying documents that are very dissimilar from previously seen ones\nWe hope this leaves you with some intuition that embeddings are quite versatile and\ncan be put to good use in your future projects'), Document(metadata={'source': 'text.txt'}, page_content='•You can “travel” the “meaning” space by using the elementary math operations •\nof addition and subtraction: for instance, the operation king – man + woman\n= queen. If you take the meaning (or semantic embedding) of king, subtract\nthe meaning of man, presumably you arrive at the more a
# ...
